# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirannoel/Learning-to-rank-implementation/blob/main/MSLR_10k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1:
#  Install tensorflow ranking

# %%
# !pip install -q tensorflow-ranking
# !pip install -q --upgrade tfds-nightly
# Out:
#      |████████████████████████████████| 141 kB 5.3 MB/s
#      |████████████████████████████████| 511.7 MB 6.0 kB/s
#      |████████████████████████████████| 438 kB 39.0 MB/s
#      |████████████████████████████████| 1.6 MB 53.8 MB/s
#      |████████████████████████████████| 5.8 MB 39.4 MB/s
#      |████████████████████████████████| 4.5 MB 5.3 MB/s

# %% [markdown]
# Step 2:
#  Import tensorflow ranking and tensorflow datasets.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_ranking as tfr

# %% [markdown]
# Step 3:
# Importing Dataset

# %%
# Load MSLR-WEB10K dataset from TFDS.
ds = tfds.load("mslr_web/10k_fold1", split="train")
# Out:
# Downloading and preparing dataset 1.15 GiB (download: 1.15 GiB, generated: 381.58 MiB, total: 1.52 GiB) to /root/tensorflow_datasets/mslr_web/10k_fold1/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/6000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/mslr_web/10k_fold1/1.0.0.incomplete59YOX0/mslr_web-train.tfrecord*...:   0…
# Generating vali examples...:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/mslr_web/10k_fold1/1.0.0.incomplete59YOX0/mslr_web-vali.tfrecord*...:   0%…
# Generating test examples...:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/mslr_web/10k_fold1/1.0.0.incomplete59YOX0/mslr_web-test.tfrecord*...:   0%…
# Dataset mslr_web downloaded and prepared to /root/tensorflow_datasets/mslr_web/10k_fold1/1.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# Step 4:
# Adding mask tensor

# %%
# Add a mask tensor.
ds = ds.map(lambda feature_map:{"_mask": tf.ones_like(feature_map["label"], dtype=tf.bool),    **feature_map})

# %% [markdown]
# Step 5:
# Shuffle data & create padded batches

# %%
# Shuffle data and create padded batches for queries with different lengths.
# Padded items will have False on `_mask`.
ds = ds.shuffle(buffer_size=1000).padded_batch(batch_size=32)

# %% [markdown]
# Step 6:
# Create Tuples

# %%
# Create (features, labels) tuples from data and set -1 label for masked items.
ds = ds.map (lambda 
feature_map:(feature_map, tf.where(feature_map["_mask"], feature_map.pop("label"),-1.)))

# %% [markdown]
# Step 7:
# Creating a model with Keras Functional API

# %%
# Create a model with Keras Functional API.
inputs = {    
    name: tf.keras.Input(shape=(None,1), dtype=tf.float32, name=name)
for name in ds.element_spec[0]
if name != "_mask"}
norm_inputs = [tf.keras.layers.BatchNormalization()(x)for x in inputs.values()]
x = tf.concat(norm_inputs, axis=-1)
for layer_width in[128,64,32]:  
  x = tf.keras.layers.Dense(units=layer_width)(x)  
  x = tf.keras.layers.Activation(activation=tf.nn.relu)(x)
  scores = tf.squeeze(tf.keras.layers.Dense(units=1)(x), axis=-1)

# %% [markdown]
# Step 8:
# Creating & Compiling & Training the models

# %%
# Create, compile and train the model.
model = tf.keras.Model(inputs=inputs, outputs=scores)
model.compile(    
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),    
    loss=tfr.keras.losses.SoftmaxLoss(),    
    metrics=tfr.keras.metrics.get("ndcg", topn=5, name="NDCG@5"))
model.fit(ds, epochs=3)
print(model.summary())
# Out:
# Epoch 1/3
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:566: UserWarning: Input dict contained keys ['_mask'] which did not match any model input. They will be ignored by the model.
#   inputs = self._flatten_to_reference_inputs(inputs)
# 188/188 [==============================] - 56s 152ms/step - loss: 396.1027 - NDCG@5: 0.3931
# Epoch 2/3
# 188/188 [==============================] - 29s 146ms/step - loss: 395.6828 - NDCG@5: 0.4054
# Epoch 3/3
# 188/188 [==============================] - 32s 160ms/step - loss: 395.5113 - NDCG@5: 0.4095
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  bm25_anchor (InputLayer)       [(None, None, 1)]    0           []
#
#  bm25_body (InputLayer)         [(None, None, 1)]    0           []
#
#  bm25_title (InputLayer)        [(None, None, 1)]    0           []
#
#  bm25_url (InputLayer)          [(None, None, 1)]    0           []
#
#  bm25_whole_document (InputLaye  [(None, None, 1)]   0           []
#  r)
#
#  boolean_model_anchor (InputLay  [(None, None, 1)]   0           []
#  er)
#
#  boolean_model_body (InputLayer  [(None, None, 1)]   0           []
#  )
#
#  boolean_model_title (InputLaye  [(None, None, 1)]   0           []
#  r)
#
#  boolean_model_url (InputLayer)  [(None, None, 1)]   0           []
#
#  boolean_model_whole_document (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  covered_query_term_number_anch  [(None, None, 1)]   0           []
#  or (InputLayer)
#
#  covered_query_term_number_body  [(None, None, 1)]   0           []
#   (InputLayer)
#
#  covered_query_term_number_titl  [(None, None, 1)]   0           []
#  e (InputLayer)
#
#  covered_query_term_number_url   [(None, None, 1)]   0           []
#  (InputLayer)
#
#  covered_query_term_number_whol  [(None, None, 1)]   0           []
#  e_document (InputLayer)
#
#  covered_query_term_ratio_ancho  [(None, None, 1)]   0           []
#  r (InputLayer)
#
#  covered_query_term_ratio_body   [(None, None, 1)]   0           []
#  (InputLayer)
#
#  covered_query_term_ratio_title  [(None, None, 1)]   0           []
#   (InputLayer)
#
#  covered_query_term_ratio_url (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  covered_query_term_ratio_whole  [(None, None, 1)]   0           []
#  _document (InputLayer)
#
#  idf_anchor (InputLayer)        [(None, None, 1)]    0           []
#
#  idf_body (InputLayer)          [(None, None, 1)]    0           []
#
#  idf_title (InputLayer)         [(None, None, 1)]    0           []
#
#  idf_url (InputLayer)           [(None, None, 1)]    0           []
#
#  idf_whole_document (InputLayer  [(None, None, 1)]   0           []
#  )
#
#  inlink_number (InputLayer)     [(None, None, 1)]    0           []
#
#  length_of_url (InputLayer)     [(None, None, 1)]    0           []
#
#  lmir_abs_anchor (InputLayer)   [(None, None, 1)]    0           []
#
#  lmir_abs_body (InputLayer)     [(None, None, 1)]    0           []
#
#  lmir_abs_title (InputLayer)    [(None, None, 1)]    0           []
#
#  lmir_abs_url (InputLayer)      [(None, None, 1)]    0           []
#
#  lmir_abs_whole_document (Input  [(None, None, 1)]   0           []
#  Layer)
#
#  lmir_dir_anchor (InputLayer)   [(None, None, 1)]    0           []
#
#  lmir_dir_body (InputLayer)     [(None, None, 1)]    0           []
#
#  lmir_dir_title (InputLayer)    [(None, None, 1)]    0           []
#
#  lmir_dir_url (InputLayer)      [(None, None, 1)]    0           []
#
#  lmir_dir_whole_document (Input  [(None, None, 1)]   0           []
#  Layer)
#
#  lmir_jm_anchor (InputLayer)    [(None, None, 1)]    0           []
#
#  lmir_jm_body (InputLayer)      [(None, None, 1)]    0           []
#
#  lmir_jm_title (InputLayer)     [(None, None, 1)]    0           []
#
#  lmir_jm_url (InputLayer)       [(None, None, 1)]    0           []
#
#  lmir_jm_whole_document (InputL  [(None, None, 1)]   0           []
#  ayer)
#
#  max_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_anchor (Input
#  Layer)
#
#  max_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_body (InputLa
#  yer)
#
#  max_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_title (InputL
#  ayer)
#
#  max_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_url (InputLay
#  er)
#
#  max_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_whole_documen
#  t (InputLayer)
#
#  max_of_term_frequency_anchor (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  max_of_term_frequency_body (In  [(None, None, 1)]   0           []
#  putLayer)
#
#  max_of_term_frequency_title (I  [(None, None, 1)]   0           []
#  nputLayer)
#
#  max_of_term_frequency_url (Inp  [(None, None, 1)]   0           []
#  utLayer)
#
#  max_of_term_frequency_whole_do  [(None, None, 1)]   0           []
#  cument (InputLayer)
#
#  max_of_tf_idf_anchor (InputLay  [(None, None, 1)]   0           []
#  er)
#
#  max_of_tf_idf_body (InputLayer  [(None, None, 1)]   0           []
#  )
#
#  max_of_tf_idf_title (InputLaye  [(None, None, 1)]   0           []
#  r)
#
#  max_of_tf_idf_url (InputLayer)  [(None, None, 1)]   0           []
#
#  max_of_tf_idf_whole_document (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  mean_of_stream_length_normaliz  [(None, None, 1)]   0           []
#  ed_term_frequency_anchor (Inpu
#  tLayer)
#
#  mean_of_stream_length_normaliz  [(None, None, 1)]   0           []
#  ed_term_frequency_body (InputL
#  ayer)
#
#  mean_of_stream_length_normaliz  [(None, None, 1)]   0           []
#  ed_term_frequency_title (Input
#  Layer)
#
#  mean_of_stream_length_normaliz  [(None, None, 1)]   0           []
#  ed_term_frequency_url (InputLa
#  yer)
#
#  mean_of_stream_length_normaliz  [(None, None, 1)]   0           []
#  ed_term_frequency_whole_docume
#  nt (InputLayer)
#
#  mean_of_term_frequency_anchor   [(None, None, 1)]   0           []
#  (InputLayer)
#
#  mean_of_term_frequency_body (I  [(None, None, 1)]   0           []
#  nputLayer)
#
#  mean_of_term_frequency_title (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  mean_of_term_frequency_url (In  [(None, None, 1)]   0           []
#  putLayer)
#
#  mean_of_term_frequency_whole_d  [(None, None, 1)]   0           []
#  ocument (InputLayer)
#
#  mean_of_tf_idf_anchor (InputLa  [(None, None, 1)]   0           []
#  yer)
#
#  mean_of_tf_idf_body (InputLaye  [(None, None, 1)]   0           []
#  r)
#
#  mean_of_tf_idf_title (InputLay  [(None, None, 1)]   0           []
#  er)
#
#  mean_of_tf_idf_url (InputLayer  [(None, None, 1)]   0           []
#  )
#
#  mean_of_tf_idf_whole_document   [(None, None, 1)]   0           []
#  (InputLayer)
#
#  min_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_anchor (Input
#  Layer)
#
#  min_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_body (InputLa
#  yer)
#
#  min_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_title (InputL
#  ayer)
#
#  min_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_url (InputLay
#  er)
#
#  min_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_whole_documen
#  t (InputLayer)
#
#  min_of_term_frequency_anchor (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  min_of_term_frequency_body (In  [(None, None, 1)]   0           []
#  putLayer)
#
#  min_of_term_frequency_title (I  [(None, None, 1)]   0           []
#  nputLayer)
#
#  min_of_term_frequency_url (Inp  [(None, None, 1)]   0           []
#  utLayer)
#
#  min_of_term_frequency_whole_do  [(None, None, 1)]   0           []
#  cument (InputLayer)
#
#  min_of_tf_idf_anchor (InputLay  [(None, None, 1)]   0           []
#  er)
#
#  min_of_tf_idf_body (InputLayer  [(None, None, 1)]   0           []
#  )
#
#  min_of_tf_idf_title (InputLaye  [(None, None, 1)]   0           []
#  r)
#
#  min_of_tf_idf_url (InputLayer)  [(None, None, 1)]   0           []
#
#  min_of_tf_idf_whole_document (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  number_of_slash_in_url (InputL  [(None, None, 1)]   0           []
#  ayer)
#
#  outlink_number (InputLayer)    [(None, None, 1)]    0           []
#
#  page_rank (InputLayer)         [(None, None, 1)]    0           []
#
#  quality_score (InputLayer)     [(None, None, 1)]    0           []
#
#  quality_score_2 (InputLayer)   [(None, None, 1)]    0           []
#
#  query_url_click_count (InputLa  [(None, None, 1)]   0           []
#  yer)
#
#  site_rank (InputLayer)         [(None, None, 1)]    0           []
#
#  stream_length_anchor (InputLay  [(None, None, 1)]   0           []
#  er)
#
#  stream_length_body (InputLayer  [(None, None, 1)]   0           []
#  )
#
#  stream_length_title (InputLaye  [(None, None, 1)]   0           []
#  r)
#
#  stream_length_url (InputLayer)  [(None, None, 1)]   0           []
#
#  stream_length_whole_document (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  sum_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_anchor (Input
#  Layer)
#
#  sum_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_body (InputLa
#  yer)
#
#  sum_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_title (InputL
#  ayer)
#
#  sum_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_url (InputLay
#  er)
#
#  sum_of_stream_length_normalize  [(None, None, 1)]   0           []
#  d_term_frequency_whole_documen
#  t (InputLayer)
#
#  sum_of_term_frequency_anchor (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  sum_of_term_frequency_body (In  [(None, None, 1)]   0           []
#  putLayer)
#
#  sum_of_term_frequency_title (I  [(None, None, 1)]   0           []
#  nputLayer)
#
#  sum_of_term_frequency_url (Inp  [(None, None, 1)]   0           []
#  utLayer)
#
#  sum_of_term_frequency_whole_do  [(None, None, 1)]   0           []
#  cument (InputLayer)
#
#  sum_of_tf_idf_anchor (InputLay  [(None, None, 1)]   0           []
#  er)
#
#  sum_of_tf_idf_body (InputLayer  [(None, None, 1)]   0           []
#  )
#
#  sum_of_tf_idf_title (InputLaye  [(None, None, 1)]   0           []
#  r)
#
#  sum_of_tf_idf_url (InputLayer)  [(None, None, 1)]   0           []
#
#  sum_of_tf_idf_whole_document (  [(None, None, 1)]   0           []
#  InputLayer)
#
#  url_click_count (InputLayer)   [(None, None, 1)]    0           []
#
#  url_dwell_time (InputLayer)    [(None, None, 1)]    0           []
#
#  variance_of_stream_length_norm  [(None, None, 1)]   0           []
#  alized_term_frequency_anchor (
#  InputLayer)
#
#  variance_of_stream_length_norm  [(None, None, 1)]   0           []
#  alized_term_frequency_body (In
#  putLayer)
#
#  variance_of_stream_length_norm  [(None, None, 1)]   0           []
#  alized_term_frequency_title (I
#  nputLayer)
#
#  variance_of_stream_length_norm  [(None, None, 1)]   0           []
#  alized_term_frequency_url (Inp
#  utLayer)
#
#  variance_of_stream_length_norm  [(None, None, 1)]   0           []
#  alized_term_frequency_whole_do
#  cument (InputLayer)
#
#  variance_of_term_frequency_anc  [(None, None, 1)]   0           []
#  hor (InputLayer)
#
#  variance_of_term_frequency_bod  [(None, None, 1)]   0           []
#  y (InputLayer)
#
#  variance_of_term_frequency_tit  [(None, None, 1)]   0           []
#  le (InputLayer)
#
#  variance_of_term_frequency_url  [(None, None, 1)]   0           []
#   (InputLayer)
#
#  variance_of_term_frequency_who  [(None, None, 1)]   0           []
#  le_document (InputLayer)
#
#  variance_of_tf_idf_anchor (Inp  [(None, None, 1)]   0           []
#  utLayer)
#
#  variance_of_tf_idf_body (Input  [(None, None, 1)]   0           []
#  Layer)
#
#  variance_of_tf_idf_title (Inpu  [(None, None, 1)]   0           []
#  tLayer)
#
#  variance_of_tf_idf_url (InputL  [(None, None, 1)]   0           []
#  ayer)
#
#  variance_of_tf_idf_whole_docum  [(None, None, 1)]   0           []
#  ent (InputLayer)
#
#  vector_space_model_anchor (Inp  [(None, None, 1)]   0           []
#  utLayer)
#
#  vector_space_model_body (Input  [(None, None, 1)]   0           []
#  Layer)
#
#  vector_space_model_title (Inpu  [(None, None, 1)]   0           []
#  tLayer)
#
#  vector_space_model_url (InputL  [(None, None, 1)]   0           []
#  ayer)
#
#  vector_space_model_whole_docum  [(None, None, 1)]   0           []
#  ent (InputLayer)
#
#  batch_normalization (BatchNorm  (None, None, 1)     4           ['bm25_anchor[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, None, 1)     4           ['bm25_body[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, None, 1)     4           ['bm25_title[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, None, 1)     4           ['bm25_url[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, None, 1)     4           ['bm25_whole_document[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, None, 1)     4           ['boolean_model_anchor[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, None, 1)     4           ['boolean_model_body[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, None, 1)     4           ['boolean_model_title[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, None, 1)     4           ['boolean_model_url[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, None, 1)     4           ['boolean_model_whole_document[0]
#  rmalization)                                                    [0]']
#
#  batch_normalization_10 (BatchN  (None, None, 1)     4           ['covered_query_term_number_ancho
#  ormalization)                                                   r[0][0]']
#
#  batch_normalization_11 (BatchN  (None, None, 1)     4           ['covered_query_term_number_body[
#  ormalization)                                                   0][0]']
#
#  batch_normalization_12 (BatchN  (None, None, 1)     4           ['covered_query_term_number_title
#  ormalization)                                                   [0][0]']
#
#  batch_normalization_13 (BatchN  (None, None, 1)     4           ['covered_query_term_number_url[0
#  ormalization)                                                   ][0]']
#
#  batch_normalization_14 (BatchN  (None, None, 1)     4           ['covered_query_term_number_whole
#  ormalization)                                                   _document[0][0]']
#
#  batch_normalization_15 (BatchN  (None, None, 1)     4           ['covered_query_term_ratio_anchor
#  ormalization)                                                   [0][0]']
#
#  batch_normalization_16 (BatchN  (None, None, 1)     4           ['covered_query_term_ratio_body[0
#  ormalization)                                                   ][0]']
#
#  batch_normalization_17 (BatchN  (None, None, 1)     4           ['covered_query_term_ratio_title[
#  ormalization)                                                   0][0]']
#
#  batch_normalization_18 (BatchN  (None, None, 1)     4           ['covered_query_term_ratio_url[0]
#  ormalization)                                                   [0]']
#
#  batch_normalization_19 (BatchN  (None, None, 1)     4           ['covered_query_term_ratio_whole_
#  ormalization)                                                   document[0][0]']
#
#  batch_normalization_20 (BatchN  (None, None, 1)     4           ['idf_anchor[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, None, 1)     4           ['idf_body[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, None, 1)     4           ['idf_title[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, None, 1)     4           ['idf_url[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, None, 1)     4           ['idf_whole_document[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, None, 1)     4           ['inlink_number[0][0]']
#  ormalization)
# ...
#
#  batch_normalization_135 (Batch  (None, None, 1)     4           ['vector_space_model_whole_docume
#  Normalization)                                                  nt[0][0]']
#
#  tf.concat (TFOpLambda)         (None, None, 136)    0           ['batch_normalization[0][0]',
#                                                                   'batch_normalization_1[0][0]',
#                                                                   'batch_normalization_2[0][0]',
#                                                                   'batch_normalization_3[0][0]',
#                                                                   'batch_normalization_4[0][0]',
#                                                                   'batch_normalization_5[0][0]',
#                                                                   'batch_normalization_6[0][0]',
#                                                                   'batch_normalization_7[0][0]',
#                                                                   'batch_normalization_8[0][0]',
#                                                                   'batch_normalization_9[0][0]',
#                                                                   'batch_normalization_10[0][0]',
#                                                                   'batch_normalization_11[0][0]',
#                                                                   'batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]',
#                                                                   'batch_normalization_15[0][0]',
#                                                                   'batch_normalization_16[0][0]',
#                                                                   'batch_normalization_17[0][0]',
#                                                                   'batch_normalization_18[0][0]',
#                                                                   'batch_normalization_19[0][0]',
#                                                                   'batch_normalization_20[0][0]',
#                                                                   'batch_normalization_21[0][0]',
#                                                                   'batch_normalization_22[0][0]',
#                                                                   'batch_normalization_23[0][0]',
#                                                                   'batch_normalization_24[0][0]',
#                                                                   'batch_normalization_25[0][0]',
#                                                                   'batch_normalization_26[0][0]',
#                                                                   'batch_normalization_27[0][0]',
#                                                                   'batch_normalization_28[0][0]',
#                                                                   'batch_normalization_29[0][0]',
#                                                                   'batch_normalization_30[0][0]',
#                                                                   'batch_normalization_31[0][0]',
#                                                                   'batch_normalization_32[0][0]',
#                                                                   'batch_normalization_33[0][0]',
#                                                                   'batch_normalization_34[0][0]',
#                                                                   'batch_normalization_35[0][0]',
#                                                                   'batch_normalization_36[0][0]',
#                                                                   'batch_normalization_37[0][0]',
#                                                                   'batch_normalization_38[0][0]',
#                                                                   'batch_normalization_39[0][0]',
#                                                                   'batch_normalization_40[0][0]',
#                                                                   'batch_normalization_41[0][0]',
#                                                                   'batch_normalization_42[0][0]',
#                                                                   'batch_normalization_43[0][0]',
#                                                                   'batch_normalization_44[0][0]',
#                                                                   'batch_normalization_45[0][0]',
#                                                                   'batch_normalization_46[0][0]',
#                                                                   'batch_normalization_47[0][0]',
#                                                                   'batch_normalization_48[0][0]',
#                                                                   'batch_normalization_49[0][0]',
#                                                                   'batch_normalization_50[0][0]',
#                                                                   'batch_normalization_51[0][0]',
#                                                                   'batch_normalization_52[0][0]',
#                                                                   'batch_normalization_53[0][0]',
#                                                                   'batch_normalization_54[0][0]',
#                                                                   'batch_normalization_55[0][0]',
#                                                                   'batch_normalization_56[0][0]',
#                                                                   'batch_normalization_57[0][0]',
#                                                                   'batch_normalization_58[0][0]',
#                                                                   'batch_normalization_59[0][0]',
#                                                                   'batch_normalization_60[0][0]',
#                                                                   'batch_normalization_61[0][0]',
#                                                                   'batch_normalization_62[0][0]',
#                                                                   'batch_normalization_63[0][0]',
#                                                                   'batch_normalization_64[0][0]',
#                                                                   'batch_normalization_65[0][0]',
#                                                                   'batch_normalization_66[0][0]',
#                                                                   'batch_normalization_67[0][0]',
#                                                                   'batch_normalization_68[0][0]',
#                                                                   'batch_normalization_69[0][0]',
#                                                                   'batch_normalization_70[0][0]',
#                                                                   'batch_normalization_71[0][0]',
#                                                                   'batch_normalization_72[0][0]',
#                                                                   'batch_normalization_73[0][0]',
#                                                                   'batch_normalization_74[0][0]',
#                                                                   'batch_normalization_75[0][0]',
#                                                                   'batch_normalization_76[0][0]',
#                                                                   'batch_normalization_77[0][0]',
#                                                                   'batch_normalization_78[0][0]',
#                                                                   'batch_normalization_79[0][0]',
#                                                                   'batch_normalization_80[0][0]',
#                                                                   'batch_normalization_81[0][0]',
#                                                                   'batch_normalization_82[0][0]',
#                                                                   'batch_normalization_83[0][0]',
#                                                                   'batch_normalization_84[0][0]',
#                                                                   'batch_normalization_85[0][0]',
#                                                                   'batch_normalization_86[0][0]',
#                                                                   'batch_normalization_87[0][0]',
#                                                                   'batch_normalization_88[0][0]',
#                                                                   'batch_normalization_89[0][0]',
#                                                                   'batch_normalization_90[0][0]',
#                                                                   'batch_normalization_91[0][0]',
#                                                                   'batch_normalization_92[0][0]',
#                                                                   'batch_normalization_93[0][0]',
#                                                                   'batch_normalization_94[0][0]',
#                                                                   'batch_normalization_95[0][0]',
#                                                                   'batch_normalization_96[0][0]',
#                                                                   'batch_normalization_97[0][0]',
#                                                                   'batch_normalization_98[0][0]',
#                                                                   'batch_normalization_99[0][0]',
#                                                                   'batch_normalization_100[0][0]',
#                                                                   'batch_normalization_101[0][0]',
#                                                                   'batch_normalization_102[0][0]',
#                                                                   'batch_normalization_103[0][0]',
#                                                                   'batch_normalization_104[0][0]',
#                                                                   'batch_normalization_105[0][0]',
#                                                                   'batch_normalization_106[0][0]',
#                                                                   'batch_normalization_107[0][0]',
#                                                                   'batch_normalization_108[0][0]',
#                                                                   'batch_normalization_109[0][0]',
#                                                                   'batch_normalization_110[0][0]',
#                                                                   'batch_normalization_111[0][0]',
#                                                                   'batch_normalization_112[0][0]',
#                                                                   'batch_normalization_113[0][0]',
#                                                                   'batch_normalization_114[0][0]',
#                                                                   'batch_normalization_115[0][0]',
#                                                                   'batch_normalization_116[0][0]',
#                                                                   'batch_normalization_117[0][0]',
#                                                                   'batch_normalization_118[0][0]',
#                                                                   'batch_normalization_119[0][0]',
#                                                                   'batch_normalization_120[0][0]',
#                                                                   'batch_normalization_121[0][0]',
#                                                                   'batch_normalization_122[0][0]',
#                                                                   'batch_normalization_123[0][0]',
#                                                                   'batch_normalization_124[0][0]',
#                                                                   'batch_normalization_125[0][0]',
#                                                                   'batch_normalization_126[0][0]',
#                                                                   'batch_normalization_127[0][0]',
#                                                                   'batch_normalization_128[0][0]',
#                                                                   'batch_normalization_129[0][0]',
#                                                                   'batch_normalization_130[0][0]',
#                                                                   'batch_normalization_131[0][0]',
#                                                                   'batch_normalization_132[0][0]',
#                                                                   'batch_normalization_133[0][0]',
#                                                                   'batch_normalization_134[0][0]',
#                                                                   'batch_normalization_135[0][0]']
#
#  dense (Dense)                  (None, None, 128)    17536       ['tf.concat[0][0]']
#
#  activation (Activation)        (None, None, 128)    0           ['dense[0][0]']
#
#  dense_2 (Dense)                (None, None, 64)     8256        ['activation[0][0]']
#
#  activation_1 (Activation)      (None, None, 64)     0           ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, None, 32)     2080        ['activation_1[0][0]']
#
#  activation_2 (Activation)      (None, None, 32)     0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, None, 1)      33          ['activation_2[0][0]']
#
#  tf.compat.v1.squeeze_2 (TFOpLa  (None, None)        0           ['dense_5[0][0]']
#  mbda)
#
# ==================================================================================================
# Total params: 28,449
# Trainable params: 28,177
# Non-trainable params: 272
# __________________________________________________________________________________________________
# None
